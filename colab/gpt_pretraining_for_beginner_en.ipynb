# %% [markdown]
# #Optimizer AdamW vs Sophia
# #中文GPT预训练框架

# %% [markdown]
# #Changelog
# 2023/6/1 新增自训练、GPT2-XL的sample测试，新增预训练模型loss测试。

# %%
# !python -V
#!pip3 install --pre torch --index-url https://download.pytorch.org/whl/nightly/cpu
#!pip3 install numpy --pre torch --force-reinstall --index-url https://download.pytorch.org/whl/nightly/cu117
# !pip install transformers datasets tiktoken blobfile
# !python -V
# Out:
# Python 3.10.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.5 MB/s eta 0:00:00
# ...
# Python 3.10.12

# %% [markdown]
# #Build Train and Dev binary files.
# Manually move generated train.bin and dev.bin to data/web/ folder.

# %%
# %cd /content/drive/MyDrive/Code
# !python prepare.py
# Out:
# /content/drive/MyDrive/Code
# Found cached dataset text (/root/.cache/huggingface/datasets/text/default-889d885549c9b143/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
# 100% 1/1 [00:00<00:00, 466.50it/s]
# tokenization finished
# writing /content/drive/MyDrive/Code/train.bin...
# 100% 39800/39800 [00:02<00:00, 17988.84it/s]
# writing /content/drive/MyDrive/Code/val.bin...
# 100% 200/200 [00:00<00:00, 23821.12it/s]

# %%
# %cd /content/drive/MyDrive/Code
# !rm /content/drive/MyDrive/Code/data/web/*.bin
# !mv train.bin val.bin data/web/
# Out:
# /content/drive/MyDrive/Code

# %%
# %cd /content/drive/MyDrive/Code
# !python train.py --device=cuda --compile=True --dtype=float16 --gradient_accumulation_steps=1 --eval_iters=1 --log_interval=10 --block_size=256 --batch_size=64 --dropout=0.2 --n_layer=6 --n_head=6 --n_embd=384 --max_iters=5000 --lr_decay_iters=5000 --learning_rate=1e-3 --min_lr=1e-4 --beta2=0.99 --warmup_iters=100
# Out:
# /content/drive/MyDrive/Code
# Overriding: device = cuda
# Overriding: compile = True
# Overriding: dtype = float16
# Overriding: gradient_accumulation_steps = 1
# Overriding: eval_iters = 1
# Overriding: log_interval = 10
# Overriding: block_size = 256
# Overriding: batch_size = 64
# Overriding: dropout = 0.2
# Overriding: n_layer = 6
# Overriding: n_head = 6
# Overriding: n_embd = 384
# Overriding: max_iters = 5000
# Overriding: lr_decay_iters = 5000
# Overriding: learning_rate = 0.001
# Overriding: min_lr = 0.0001
# Overriding: beta2 = 0.99
# Overriding: warmup_iters = 100
# tokens per iteration will be: 16,384
# Initializing a new model from scratch
# defaulting to vocab_size of GPT-2 to 1001 (1024 rounded up for efficiency)
# number of parameters: 11.01M
# compiling the model... (takes a ~minute)
# step 0: train loss 6.9574, val loss 6.9534
# [2023-06-27 14:39:09,783] torch._inductor.utils: [WARNING] using triton random, expect difference from eager
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python train_adamw.py --device=cuda --compile=True --dtype=float16 --gradient_accumulation_steps=1 --eval_iters=1 --log_interval=10 --block_size=256 --batch_size=64 --dropout=0.2 --n_layer=6 --n_head=6 --n_embd=384 --max_iters=5000 --lr_decay_iters=5000 --learning_rate=1e-3 --min_lr=1e-4 --beta2=0.99 --warmup_iters=100

# %% [markdown]
# #Sample/Inference
# 使用已训练模型测试文本生成功能。例如：
# ```
# python sample.py \
#     --out_dir=out  \
#     --start="" \
#     --num_samples=5 --max_new_tokens=100
# ```

# %%
# %cd /content/drive/MyDrive/Code
# !python sample.py --out_dir=out --device=cuda --dtype=float16 --compile=True
# Out:
# /content/drive/MyDrive/Code
# Overriding: out_dir = out
# Overriding: device = cuda
# Overriding: dtype = float16
# Overriding: compile = True
# number of parameters: 11.01M
# No meta.pkl found, assuming GPT-2 encodings...
#
# ...
